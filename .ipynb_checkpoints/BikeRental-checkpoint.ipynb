# %% [markdown]
# # Bike Rental Project

# %% [markdown]
# ## Exploratory data analysis

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./biking_dataset.csv", sep= ";")

# %%
df.shape
# Out:
# (900, 8)

# %%
df.head()
# Out:
#             City Weather Condition  Rider Age Bike Model  Ride Duration (min)  \
# 0         Berlin             Rainy       53.0   Standard                 62.0
# 1  San Francisco            Cloudy       39.0   Standard                  5.0
# 2         Berlin             Sunny       43.0   Electric                106.0
# 3  San Francisco            Cloudy       24.0   Standard                119.0
# 4       New York             Sunny       24.0   Mountain                 11.0
#
#   Distance Covered (km) Rider Satisfaction Bike Rental Cost ($)
# 0                  2,25               High                22,63
# 1                 21,67             Medium                 7,87
# 2                  28,4               High                 39,4
# 3                  5,66                Low                37,63
# 4                 25,74                Low                13,12

# %%
df.tail()
# Out:
#               City Weather Condition  Rider Age Bike Model  \
# 895       New York             Rainy       55.0   Electric
# 896         London            Cloudy       47.0   Mountain
# 897  San Francisco             Sunny       49.0   Mountain
# 898        Chicago             Sunny       19.0   Mountain
# 899         Dublin             Rainy       37.0   Standard
#
#      Ride Duration (min) Distance Covered (km) Rider Satisfaction  \
# 895                 55.0                 28,35             Medium
# 896                 14.0                 11,99               High
# 897                 23.0                  2,78               High
# 898                110.0                  2,27               High
# 899                 17.0                   9,7             Medium
#
#     Bike Rental Cost ($)
# 895                 26,3
# 896                13,78
# 897                20,47
# 898                39,62
# 899                13,02

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   City                   890 non-null    object
#  1   Weather Condition      889 non-null    object
#  2   Rider Age              885 non-null    float64
#  3   Bike Model             890 non-null    object
#  4   Ride Duration (min)    887 non-null    float64
#  5   Distance Covered (km)  887 non-null    object
#  6   Rider Satisfaction     889 non-null    object
#  7   Bike Rental Cost ($)   891 non-null    object
# dtypes: float64(2), object(6)
# memory usage: 56.4+ KB

# %% [markdown]
# It can be seen that there are missing values in all of the features, as the number of observations is 900 but the maximum number of observations here is 890.
# It can also be seen that some variables that should be numerical, are being taken as if they were categorical.

# %% [markdown]
# In order to change the categorical variables into numerical, I will check the cleanliness of the data. I want to know whether the features not only contain commas, but they also contain dots, which might make the interpretation difficult.

# %%
df[df["Bike Rental Cost ($)" ].str.find(".") != -1] #Return all rows where a dot is found in Bike Rental Cost
# Out:
#               City Weather Condition  Rider Age Bike Model  \
# 90         Chicago             Rainy       60.0   Standard
# 179         Berlin             Sunny       59.0   Mountain
# 251         London            Cloudy       18.0   Electric
# 342            NaN             Rainy       21.0   Standard
# 463  San Francisco               NaN       57.0   Electric
# 630  San Francisco             Snowy       43.0   Standard
# 660         Berlin             Sunny       18.0   Electric
# 794  San Francisco            Cloudy        NaN   Mountain
# 856        Chicago               NaN       25.0   Standard
#
#      Ride Duration (min) Distance Covered (km) Rider Satisfaction  \
# 90                  73.0                   NaN               High
# 179                 72.0                 24,96                NaN
# 251                 68.0                 15,57                NaN
# 342                 83.0                 28,77             Medium
# 463                 92.0                 19,05                Low
# 630                113.0                 27,45                NaN
# 660                 69.0                  15,1                NaN
# 794                 88.0                 20,44                Low
# 856                 32.0                  3,45             Medium
#
#     Bike Rental Cost ($)
# 90                   NaN
# 179                  NaN
# 251                  NaN
# 342                  NaN
# 463                  NaN
# 630                  NaN
# 660                  NaN
# 794                  NaN
# 856                  NaN

# %%
df[df["Distance Covered (km)" ].str.find(".") != -1] #I do the same for the distance.
# Out:
#               City Weather Condition  Rider Age Bike Model  \
# 15        New York               NaN       41.0   Standard
# 90         Chicago             Rainy       60.0   Standard
# 119         Dublin            Cloudy       49.0   Mountain
# 218            NaN             Sunny       31.0   Standard
# 284         Berlin             Rainy        NaN   Mountain
# 295         Berlin             Sunny       60.0   Standard
# 308       New York             Snowy       37.0        NaN
# 367         Berlin               NaN       51.0   Mountain
# 434  San Francisco             Snowy       41.0   Standard
# 446        Chicago             Snowy        NaN   Standard
# 475        Chicago            Cloudy        NaN   Electric
# 623         London            Cloudy       41.0        NaN
# 894         Dublin             Snowy       56.0   Mountain
#
#      Ride Duration (min) Distance Covered (km) Rider Satisfaction  \
# 15                  53.0                   NaN             Medium
# 90                  73.0                   NaN               High
# 119                119.0                   NaN             Medium
# 218                 61.0                   NaN             Medium
# 284                 73.0                   NaN               High
# 295                  NaN                   NaN             Medium
# 308                 97.0                   NaN                Low
# 367                 65.0                   NaN               High
# 434                  NaN                   NaN             Medium
# 446                 16.0                   NaN               High
# 475                107.0                   NaN             Medium
# 623                 56.0                   NaN                Low
# 894                 98.0                   NaN                Low
#
#     Bike Rental Cost ($)
# 15                 21,24
# 90                   NaN
# 119                40,66
# 218                20,23
# 284                32,13
# 295                35,56
# 308                 33,4
# 367                28,31
# 434                18,26
# 446                13,03
# 475                37,51
# 623                 21,8
# 894                38,59

# %% [markdown]
# All of the values are NA, so I can proceed to convert into numerical.

# %%
#Replace the , for a . and change the type to numerical
df["Bike Rental Cost ($)" ] =  df["Bike Rental Cost ($)"].str.replace(",",".").astype("float64")
df["Distance Covered (km)" ] =  df["Distance Covered (km)"].str.replace(",",".").astype("float64")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   City                   890 non-null    object
#  1   Weather Condition      889 non-null    object
#  2   Rider Age              885 non-null    float64
#  3   Bike Model             890 non-null    object
#  4   Ride Duration (min)    887 non-null    float64
#  5   Distance Covered (km)  887 non-null    float64
#  6   Rider Satisfaction     889 non-null    object
#  7   Bike Rental Cost ($)   891 non-null    float64
# dtypes: float64(4), object(4)
# memory usage: 56.4+ KB

# %%
df.isna().sum()
# Out:
# City                     10
# Weather Condition        11
# Rider Age                15
# Bike Model               10
# Ride Duration (min)      13
# Distance Covered (km)    13
# Rider Satisfaction       11
# Bike Rental Cost ($)      9
# dtype: int64

# %% [markdown]
# Out of 900 entries, a maximum of 92 contain NA values. This represents 10% of the data. Therefore, I will delete them from the dataset.

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (853, 9)

# %% [markdown]
# ### Outlier detection and feature engineering

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df)
# Out:
# <Axes: >

# %% [markdown]
# In the previous boxplots, no outliers are visible.
#
# However in the previous data exploration I have noticed that some cyclists have a very short time for the distance they have covered.
#
# For example, in the line 1. 5 minutes for 21,67 km. That would mean that person went at 260 Km/hour. I will create a new feature, speed. It will help me analyze any outliers that I may be missing in distance or time because the analysis I'm performing is univariate.

# %%
df ["Speed km/h"] = df["Distance Covered (km)"]/(df["Ride Duration (min)"]/60)

# %%
df
# Out:
#               City Weather Condition  Rider Age Bike Model  \
# 0           Berlin             Rainy       53.0   Standard
# 1    San Francisco            Cloudy       39.0   Standard
# 2           Berlin             Sunny       43.0   Electric
# 3    San Francisco            Cloudy       24.0   Standard
# 4         New York             Sunny       24.0   Mountain
# ..             ...               ...        ...        ...
# 895       New York             Rainy       55.0   Electric
# 896         London            Cloudy       47.0   Mountain
# 897  San Francisco             Sunny       49.0   Mountain
# 898        Chicago             Sunny       19.0   Mountain
# 899         Dublin             Rainy       37.0   Standard
#
#      Ride Duration (min)  Distance Covered (km) Rider Satisfaction  \
# 0                   62.0                   2.25               High
# 1                    5.0                  21.67             Medium
# 2                  106.0                  28.40               High
# 3                  119.0                   5.66                Low
# 4                   11.0                  25.74                Low
# ..                   ...                    ...                ...
# 895                 55.0                  28.35             Medium
# 896                 14.0                  11.99               High
# 897                 23.0                   2.78               High
# 898                110.0                   2.27               High
# 899                 17.0                   9.70             Medium
#
#      Bike Rental Cost ($)  Speed km/h
# 0                   22.63    2.177419
# 1                    7.87  260.040000
# 2                   39.40   16.075472
# 3                   37.63    2.853782
# 4                   13.12  140.400000
# ..                    ...         ...
# 895                 26.30   30.927273
# 896                 13.78   51.385714
# 897                 20.47    7.252174
# 898                 39.62    1.238182
# 899                 13.02   34.235294
#
# [853 rows x 9 columns]

# %% [markdown]
# I will check the speed for outliers

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df)
# Out:
# <Axes: >

# %% [markdown]
# I see multiple outliers in the speed feature. I calculate the interquantile distance and check for the outliers.

# %%
a = df["Speed km/h"].quantile(0.75) #Calculating for the 75 percentile
b = df["Speed km/h"].quantile(0.25)#Calculating for the 25 percentile
lower_bound = b - 1.5*(a-b)
upper_bound = a + 1.5*(a-b)

# %%
upper_bound
# Out:
# 79.78

# %%
lower_bound
# Out:
# -31.499999999999996

# %%
df_filt = df[(df['Speed km/h'] > upper_bound) ].copy()

# %%
df_filt.sort_values(by="Speed km/h")
# Out:
#               City Weather Condition  Rider Age Bike Model  \
# 402        Chicago             Sunny       40.0   Electric
# 116  San Francisco             Snowy       53.0   Standard
# 568       New York             Sunny       19.0   Standard
# 778        Chicago            Cloudy       34.0   Electric
# 771  San Francisco             Sunny       40.0   Mountain
# ..             ...               ...        ...        ...
# 410        Chicago             Rainy       50.0   Electric
# 499         Berlin             Snowy       55.0   Standard
# 798         Berlin             Rainy       30.0   Mountain
# 574         London             Sunny       20.0   Electric
# 889  San Francisco             Snowy       49.0   Mountain
#
#      Ride Duration (min)  Distance Covered (km) Rider Satisfaction  \
# 402                 24.0                  31.98             Medium
# 116                 18.0                  24.21             Medium
# 568                 19.0                  25.74                Low
# 778                 24.0                  32.75                Low
# 771                 23.0                  31.42             Medium
# ..                   ...                    ...                ...
# 410                  6.0                  32.91               High
# 499                  5.0                  31.23               High
# 798                  5.0                  38.10               High
# 574                  5.0                  39.29                Low
# 889                  5.0                  39.30                Low
#
#      Bike Rental Cost ($)  Speed km/h
# 402                 21.59   79.950000
# 116                 12.61   80.700000
# 568                 10.21   81.284211
# 778                 16.96   81.875000
# 771                 19.29   81.965217
# ..                    ...         ...
# 410                 18.78  329.100000
# 499                  9.36  374.760000
# 798                 12.59  457.200000
# 574                 19.05  471.480000
# 889                 10.75  471.600000
#
# [98 rows x 9 columns]

# %% [markdown]
# I can see that the outliers are distributed across multiple cities, bike models, rider satisfaction, and weather conditions. Therefore I don't deem necessary to go deeper into whether their handling will affect the structure of the data for any category substantially.

# %%
df_filt.describe()
# Out:
#        Rider Age  Ride Duration (min)  Distance Covered (km)  \
# count  98.000000            98.000000              98.000000
# mean   39.744898            12.336735              27.846735
# std    12.800863             5.258168               7.811604
# min    18.000000             5.000000               9.250000
# 25%    29.000000             8.000000              21.715000
# 50%    40.000000            12.000000              28.630000
# 75%    51.000000            15.000000              33.992500
# max    60.000000            24.000000              39.570000
#
#        Bike Rental Cost ($)  Speed km/h
# count             98.000000   98.000000
# mean              13.616020  156.674640
# std                4.043826   80.315550
# min                7.330000   79.950000
# 25%               10.310000  103.228247
# 50%               13.020000  136.860989
# 75%               16.352500  182.461607
# max               22.410000  471.600000

# %% [markdown]
# While all the distances are around the median, I can see that all the outliers have in common that the time taken was lower than the 25 percentile of the time. Therefore I will cap the maximum speed to the upper bound previously calculated and I will update the time based on that.

# %%
upper_bound = a + 1.5*(a-b)
df_filt["Speed km/h"] = upper_bound
df_filt
# Out:
#               City Weather Condition  Rider Age Bike Model  \
# 1    San Francisco            Cloudy       39.0   Standard
# 4         New York             Sunny       24.0   Mountain
# 27   San Francisco            Cloudy       32.0   Standard
# 33        New York            Cloudy       51.0   Standard
# 37        New York             Snowy       54.0   Electric
# ..             ...               ...        ...        ...
# 878         Berlin             Snowy       22.0   Mountain
# 884        Chicago             Sunny       60.0   Electric
# 889  San Francisco             Snowy       49.0   Mountain
# 890        Chicago             Snowy       54.0   Mountain
# 893         Berlin             Snowy       54.0   Electric
#
#      Ride Duration (min)  Distance Covered (km) Rider Satisfaction  \
# 1                    5.0                  21.67             Medium
# 4                   11.0                  25.74                Low
# 27                  14.0                  19.73             Medium
# 33                  20.0                  36.02                Low
# 37                  12.0                  21.85             Medium
# ..                   ...                    ...                ...
# 878                  6.0                  11.13               High
# 884                  6.0                  18.92                Low
# 889                  5.0                  39.30                Low
# 890                  6.0                  26.31               High
# 893                  6.0                  15.61               High
#
#      Bike Rental Cost ($)  Speed km/h
# 1                    7.87       79.78
# 4                   13.12       79.78
# 27                  11.59       79.78
# 33                  14.65       79.78
# 37                  16.74       79.78
# ..                    ...         ...
# 878                 13.81       79.78
# 884                 17.51       79.78
# 889                 10.75       79.78
# 890                 15.74       79.78
# 893                 17.39       79.78
#
# [98 rows x 9 columns]

# %%
df_filt["Ride Duration (min)"] = 60 * (df_filt["Distance Covered (km)"] / df_filt["Speed km/h"])
df_filt
# Out:
#               City Weather Condition  Rider Age Bike Model  \
# 1    San Francisco            Cloudy       39.0   Standard
# 4         New York             Sunny       24.0   Mountain
# 27   San Francisco            Cloudy       32.0   Standard
# 33        New York            Cloudy       51.0   Standard
# 37        New York             Snowy       54.0   Electric
# ..             ...               ...        ...        ...
# 878         Berlin             Snowy       22.0   Mountain
# 884        Chicago             Sunny       60.0   Electric
# 889  San Francisco             Snowy       49.0   Mountain
# 890        Chicago             Snowy       54.0   Mountain
# 893         Berlin             Snowy       54.0   Electric
#
#      Ride Duration (min)  Distance Covered (km) Rider Satisfaction  \
# 1              16.297318                  21.67             Medium
# 4              19.358235                  25.74                Low
# 27             14.838305                  19.73             Medium
# 33             27.089496                  36.02                Low
# 37             16.432690                  21.85             Medium
# ..                   ...                    ...                ...
# 878             8.370519                  11.13               High
# 884            14.229130                  18.92                Low
# 889            29.556280                  39.30                Low
# 890            19.786914                  26.31               High
# 893            11.739784                  15.61               High
#
#      Bike Rental Cost ($)  Speed km/h
# 1                    7.87       79.78
# 4                   13.12       79.78
# 27                  11.59       79.78
# 33                  14.65       79.78
# 37                  16.74       79.78
# ..                    ...         ...
# 878                 13.81       79.78
# 884                 17.51       79.78
# 889                 10.75       79.78
# 890                 15.74       79.78
# 893                 17.39       79.78
#
# [98 rows x 9 columns]

# %%
df_filt.describe()
# Out:
#        Rider Age  Ride Duration (min)  Distance Covered (km)  \
# count  98.000000            98.000000              98.000000
# mean   39.744898            20.942643              27.846735
# std    12.800863             5.874859               7.811604
# min    18.000000             6.956631               9.250000
# 25%    29.000000            16.331161              21.715000
# 50%    40.000000            21.531712              28.630000
# 75%    51.000000            25.564678              33.992500
# max    60.000000            29.759338              39.570000
#
#        Bike Rental Cost ($)    Speed km/h
# count             98.000000  9.800000e+01
# mean              13.616020  7.978000e+01
# std                4.043826  7.141959e-14
# min                7.330000  7.978000e+01
# 25%               10.310000  7.978000e+01
# 50%               13.020000  7.978000e+01
# 75%               16.352500  7.978000e+01
# max               22.410000  7.978000e+01

# %%
df.update(df_filt)

# %%
df.describe()
# Out:
#         Rider Age  Ride Duration (min)  Distance Covered (km)  \
# count  853.000000           853.000000             853.000000
# mean    39.262603            62.757771              20.152016
# std     12.332311            32.844263              11.226650
# min     18.000000             6.000000               0.510000
# 25%     29.000000            32.000000              10.750000
# 50%     39.000000            62.000000              19.990000
# 75%     50.000000            92.000000              29.200000
# max     60.000000           120.000000              39.870000
#
#        Bike Rental Cost ($)  Speed km/h
# count            853.000000  853.000000
# mean              26.564033   28.137938
# std                9.501788   24.467964
# min                7.330000    0.373171
# 25%               19.110000   10.230000
# 50%               27.080000   19.994366
# 75%               34.010000   38.050000
# max               48.380000   79.780000

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(df)
# Out:
# <Axes: >

# %% [markdown]
# This way the outlier speeds have been handled.

# %% [markdown]
# ### Target variable encoding and correlation analysis

# %% [markdown]
# The target variable will be customer satisfaction in this case. Since the feature is ordinal, label encoding works well.

# %%
df["Rider Satisfaction"].unique() #I get all the labels for the feature
# Out:
# array(['High', 'Medium', 'Low'], dtype=object)

# %%
df["Rider Satisfaction"] = df["Rider Satisfaction"].map({"High":2, "Medium":1, "Low":0})

# %% [markdown]
# I'm going to proceed to do a correlation analysis. I'm particularly interested in what variables correlate with the bike rental cost.

# %%
numeric_df = df.select_dtypes(include=['float64', "int64"])
cor_matrix = numeric_df.corr()

sns.set(rc={'figure.figsize':(8, 5)})
sns.heatmap(cor_matrix, vmin=-1, vmax=1, cmap ="vlag", annot=True) 
plt.show()

# %% [markdown]
# I can see the rental cost is very highly correlated with the ride duration. The target variable, rider satisfaction is not correlated with any of them.
